# %%
from calcSeoStats import SEOStats

# %%
stats = SEOStats('article1.txt', 'graph.pickle')

# %%
stats.add_additional_kw('sensitive data')
stats.add_additional_kw('sensitive information')
stats.add_additional_kw('data security')
stats.add_additional_kw('critical data')

# %%
stats.statpipeline()
# Out:
# Density of keywords:
# a 55.972696245733786
# s 42.54835039817975
# it 7.508532423208192
# data 4.323094425483505
# and 3.0716723549488054
# information 2.2753128555176336
# sensitive 2.04778156996587
# sensitive data 1.7064846416382253
# person 1.1376564277588168
# personal 1.023890784982935
# type 0.9101251422070534
# protect 0.7963594994311717
# individual 0.7963594994311717
# financial 0.7963594994311717
# health 0.7963594994311717
# types 0.7963594994311717
# security 0.6825938566552902
# all 0.6825938566552902
# breach 0.6825938566552902
# act 0.6825938566552902
# details 0.6825938566552902
# use 0.6825938566552902
# regulation 0.6825938566552902
# regulations 0.5688282138794084
# understand 0.5688282138794084
# critical 0.5688282138794084
# include 0.5688282138794084
# business 0.5688282138794084
# personal information 0.5688282138794084
# access 0.4550625711035267
# more 0.4550625711035267
# lead 0.4550625711035267
# pii 0.4550625711035267
# number 0.4550625711035267
# ...

# %%
stats.getKWstats('sensitive data')
# Out:
# {'count': 15,
#  'density': 0.017064846416382253,
#  'frequency': 0.017064846416382253}

# %%
stats.getKWstats('sensitive information')
# Out:
# {'count': 0, 'density': 0.0, 'frequency': 0.0}

# %%
stats.getKWstats('data security')
# Out:
# {'count': 1,
#  'density': 0.0011376564277588168,
#  'frequency': 0.0011376564277588168}

# %%
stats.getKWstats('regulation')
# Out:
# {'count': 6,
#  'density': 0.006825938566552901,
#  'frequency': 0.006825938566552901}
