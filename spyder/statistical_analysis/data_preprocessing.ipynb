# %%
import psycopg2
import contractions
import string
import re
import pandas as pd
import numpy as np
import networkx as nx
import nltk
from nltk.util import ngrams
import tqdm

# %%
def generate_ngrams(text, x, y):
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Generate n-grams for n ranging from x to y
    ngrams_list = []
    for n in range(x, y+1):
        ngrams_ = ngrams(words, n)
        ngrams_ = [' '.join(grams) for grams in ngrams_]
        ngrams_list.extend(ngrams_)
    
    return ngrams_list

def generate_ngrams_listofsentences(list_of_sentences, x, y):
    ngrams_list = []
    for sentence in list_of_sentences:
        ngrams_list.extend(generate_ngrams(sentence, x, y))
    return ngrams_list

# %%
def preprocess_heading(text):
    # Lowercase the text
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove contractions
    text = contractions.fix(text)
    return text

def preprocess_paragraph(text):
    # split into lines
    lines = text.split('\n')
    # remove leading and trailing spaces on each line
    lines = [line.strip() for line in lines]
    # remove empty lines
    lines = [line for line in lines if len(line) > 0]
    # Lowercase the text
    lines = [line.lower() for line in lines]
    # Remove punctuation
    lines = [line.translate(str.maketrans('', '', string.punctuation)) for line in lines]
    # Remove contractions
    lines = [contractions.fix(line) for line in lines]
    return lines

def preprocess_text(text):
    # if more than 4 words, return empty string
    if len(text.split()) > 4:
        return ''
    # Lowercase the text
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove contractions
    text = contractions.fix(text)
    return text

# %%
# connect to database
conn = psycopg2.connect(
    host="localhost",
    port=5450,
    database="postgres",
    user="postgres",
    password="postgres"
)

# create cursor
cur = conn.cursor()

# %%
# get the topics table, select random 20 rows
cur.execute("SELECT * FROM topics")
topics = cur.fetchall()

# get the columns
cols = [desc[0] for desc in cur.description]

# create dataframe
topics_df = pd.DataFrame(topics, columns=cols)

topics_df.head(20)
# Out:
#                                                 topic  \
# 0                                       communication
# 1                                              energy
# 2                           and water supply. however
# 3   the demand for infrastructure services increas...
# 4                              extreme weather events
# 5   and other climate-related phenomena pose signi...
# 6   there is a need to address issues of equity an...
# 7                particularly in developing countries
# 8   lack basic infrastructure services. rethinking...
# 9   the world needs to rethink infrastructure acce...
# 10                                     climate change
# 11                                     digitalization
# 12  and equity. by adopting innovative and sustain...
# 13  we can ensure that everyone has access to the ...
# 14                                data breach problem
# 15                                     cyber breaches
# 16                                              trend
# 17                                            numbers
# 18                                       average cost
# 19                                             breach
#
#                      topics_preprocessed
# 0                          communication
# 1                                 energy
# 2               and water supply however
# 3
# 4                 extreme weather events
# 5
# 6
# 7   particularly in developing countries
# 8
# 9
# 10                        climate change
# 11                        digitalization
# 12
# 13
# 14                   data breach problem
# 15                        cyber breaches
# 16                                 trend
# 17                               numbers
# 18                          average cost
# 19                                breach

# %%
# preprocess the topics and add it as a new column
topics_df['topics_preprocessed'] = topics_df['topic'].apply(preprocess_text)

topics_df.head(20)
# Out:
#                                                 topic  \
# 0                                       communication
# 1                                              energy
# 2                           and water supply. however
# 3   the demand for infrastructure services increas...
# 4                              extreme weather events
# 5   and other climate-related phenomena pose signi...
# 6   there is a need to address issues of equity an...
# 7                particularly in developing countries
# 8   lack basic infrastructure services. rethinking...
# 9   the world needs to rethink infrastructure acce...
# 10                                     climate change
# 11                                     digitalization
# 12  and equity. by adopting innovative and sustain...
# 13  we can ensure that everyone has access to the ...
# 14                                data breach problem
# 15                                     cyber breaches
# 16                                              trend
# 17                                            numbers
# 18                                       average cost
# 19                                             breach
#
#                      topics_preprocessed
# 0                          communication
# 1                                 energy
# 2               and water supply however
# 3
# 4                 extreme weather events
# 5
# 6
# 7   particularly in developing countries
# 8
# 9
# 10                        climate change
# 11                        digitalization
# 12
# 13
# 14                   data breach problem
# 15                        cyber breaches
# 16                                 trend
# 17                               numbers
# 18                          average cost
# 19                                breach

# %%
# print total number of topics
print('Total number of topics: ', len(topics_df))
# print number of topics with non empty preprocessed topics
print('Number of topics with non empty preprocessed topics: ', len(topics_df[topics_df['topics_preprocessed'] != '']))
# print the number of unique topics based on the preprocessed topics
print('Number of unique topics: ', len(topics_df['topics_preprocessed'].unique()))
# Out:
# Total number of topics:  67750
# Number of topics with non empty preprocessed topics:  59736
# Number of unique topics:  59522

# %%
# import data into pandas dataframe
cur.execute("SELECT * FROM resources")

# get column names
colnames = [desc[0] for desc in cur.description]

# create dataframe
df = pd.DataFrame(cur.fetchall(), columns=colnames)

# %%
# preproces the heading and content and ad them as new columns
df['heading_preprocessed'] = df['heading'].apply(preprocess_heading)
df['content_preprocessed'] = df['content'].apply(preprocess_paragraph)

df.head()
# Out:
#                                                  url hid  \
# 0  https://adaptive.live/blog/rethink-infrastruct...  h2
# 1  https://adaptive.live/blog/rethink-infrastruct...  h2
# 2  https://adaptive.live/blog/rethink-infrastruct...  h2
# 3  https://adaptive.live/blog/rethink-infrastruct...  h3
# 4  https://adaptive.live/blog/rethink-infrastruct...  h3
#
#                                              heading  hnum  next_heading  \
# 0                 The Increasing Data Breach Problem     1           NaN
# 1  Insider Threat: a new problem within organizat...     2           NaN
# 2        Complexity of the Modern-day Infrastructure     3           4.0
# 3                      Remote-first trend post-covid     4           NaN
# 4                           Increased Cloud Adoption     5           NaN
#
#    subheading                                            content  \
# 0         2.0  The problem of cyber breaches is only getting ...
# 1         3.0  Recently, a new type of threat has started imp...
# 2         8.0  In order to understand the problems with infra...
# 3         5.0  In March 2020 Covid struck, and remote work we...
# 4         6.0  A common infrastructure setup that companies u...
#
#                                               topics  \
# 0  ["data breach problem", "cyber breaches", "tre...
# 1  ["insider threats", "cyber security risk", "or...
# 2  ["complexity", "modern-day infrastructure", "p...
# 3  ["remote work", "covid", "mainstream", "rushed...
# 4  ["cloud adoption", "infrastructure setup", "on...
#
#                                 heading_preprocessed  \
# 0                 the increasing data breach problem
# 1  insider threat a new problem within organizations
# 2         complexity of the modernday infrastructure
# 3                        remotefirst trend postcovid
# 4                           increased cloud adoption
#
#                                 content_preprocessed heading_ngrams  \
# 0  [the problem of cyber breaches is only getting...           None
# 1  [recently a new type of threat has started imp...           None
# 2  [in order to understand the problems with infr...           None
# 3  [in march 2020 covid struck and remote work we...           None
# 4  [a common infrastructure setup that companies ...           None
#
#   content_ngrams  id
# 0           None   2
# 1           None   3
# 2           None   4
# 3           None   5
# 4           None   6

# %%
# generate ngrams for heading rangint (1-4) and add it as a new column
df['heading_ngrams'] = df['heading_preprocessed'].apply(generate_ngrams, args=(1,4))

df.head()
# Out:
#                                                  url hid  \
# 0  https://adaptive.live/blog/rethink-infrastruct...  h2
# 1  https://adaptive.live/blog/rethink-infrastruct...  h2
# 2  https://adaptive.live/blog/rethink-infrastruct...  h2
# 3  https://adaptive.live/blog/rethink-infrastruct...  h3
# 4  https://adaptive.live/blog/rethink-infrastruct...  h3
#
#                                              heading  hnum  next_heading  \
# 0                 The Increasing Data Breach Problem     1           NaN
# 1  Insider Threat: a new problem within organizat...     2           NaN
# 2        Complexity of the Modern-day Infrastructure     3           4.0
# 3                      Remote-first trend post-covid     4           NaN
# 4                           Increased Cloud Adoption     5           NaN
#
#    subheading                                            content  \
# 0         2.0  The problem of cyber breaches is only getting ...
# 1         3.0  Recently, a new type of threat has started imp...
# 2         8.0  In order to understand the problems with infra...
# 3         5.0  In March 2020 Covid struck, and remote work we...
# 4         6.0  A common infrastructure setup that companies u...
#
#                                               topics  \
# 0  ["data breach problem", "cyber breaches", "tre...
# 1  ["insider threats", "cyber security risk", "or...
# 2  ["complexity", "modern-day infrastructure", "p...
# 3  ["remote work", "covid", "mainstream", "rushed...
# 4  ["cloud adoption", "infrastructure setup", "on...
#
#                                 heading_preprocessed  \
# 0                 the increasing data breach problem
# 1  insider threat a new problem within organizations
# 2         complexity of the modernday infrastructure
# 3                        remotefirst trend postcovid
# 4                           increased cloud adoption
#
#                                 content_preprocessed  \
# 0  [the problem of cyber breaches is only getting...
# 1  [recently a new type of threat has started imp...
# 2  [in order to understand the problems with infr...
# 3  [in march 2020 covid struck and remote work we...
# 4  [a common infrastructure setup that companies ...
#
#                                       heading_ngrams content_ngrams  id
# 0  [the, increasing, data, breach, problem, the i...           None   2
# 1  [insider, threat, a, new, problem, within, org...           None   3
# 2  [complexity, of, the, modernday, infrastructur...           None   4
# 3  [remotefirst, trend, postcovid, remotefirst tr...           None   5
# 4  [increased, cloud, adoption, increased cloud, ...           None   6

# %%
# generate ngrams for content ranging (1-4) and add it as a new column
df['content_ngrams'] = df['content_preprocessed'].apply(generate_ngrams_listofsentences, args=(1,4))

df.head()
# Out:
#                                                  url hid  \
# 0  https://adaptive.live/blog/rethink-infrastruct...  h2
# 1  https://adaptive.live/blog/rethink-infrastruct...  h2
# 2  https://adaptive.live/blog/rethink-infrastruct...  h2
# 3  https://adaptive.live/blog/rethink-infrastruct...  h3
# 4  https://adaptive.live/blog/rethink-infrastruct...  h3
#
#                                              heading  hnum  next_heading  \
# 0                 The Increasing Data Breach Problem     1           NaN
# 1  Insider Threat: a new problem within organizat...     2           NaN
# 2        Complexity of the Modern-day Infrastructure     3           4.0
# 3                      Remote-first trend post-covid     4           NaN
# 4                           Increased Cloud Adoption     5           NaN
#
#    subheading                                            content  \
# 0         2.0  The problem of cyber breaches is only getting ...
# 1         3.0  Recently, a new type of threat has started imp...
# 2         8.0  In order to understand the problems with infra...
# 3         5.0  In March 2020 Covid struck, and remote work we...
# 4         6.0  A common infrastructure setup that companies u...
#
#                                               topics  \
# 0  ["data breach problem", "cyber breaches", "tre...
# 1  ["insider threats", "cyber security risk", "or...
# 2  ["complexity", "modern-day infrastructure", "p...
# 3  ["remote work", "covid", "mainstream", "rushed...
# 4  ["cloud adoption", "infrastructure setup", "on...
#
#                                 heading_preprocessed  \
# 0                 the increasing data breach problem
# 1  insider threat a new problem within organizations
# 2         complexity of the modernday infrastructure
# 3                        remotefirst trend postcovid
# 4                           increased cloud adoption
#
#                                 content_preprocessed  \
# 0  [the problem of cyber breaches is only getting...
# 1  [recently a new type of threat has started imp...
# 2  [in order to understand the problems with infr...
# 3  [in march 2020 covid struck and remote work we...
# 4  [a common infrastructure setup that companies ...
#
#                                       heading_ngrams  \
# 0  [the, increasing, data, breach, problem, the i...
# 1  [insider, threat, a, new, problem, within, org...
# 2  [complexity, of, the, modernday, infrastructur...
# 3  [remotefirst, trend, postcovid, remotefirst tr...
# 4  [increased, cloud, adoption, increased cloud, ...
#
#                                       content_ngrams  id
# 0  [the, problem, of, cyber, breaches, is, only, ...   2
# 1  [recently, a, new, type, of, threat, has, star...   3
# 2  [in, order, to, understand, the, problems, wit...   4
# 3  [in, march, 2020, covid, struck, and, remote, ...   5
# 4  [a, common, infrastructure, setup, that, compa...   6

# %%
# find the topic row from the database where the topic is energy, rollback any transaction that is in progress
conn.rollback()
cur.execute("SELECT * FROM topics WHERE topic = 'energy'")
topic = cur.fetchone()
print(topic)
# Out:
# ('energy', 'energy')

# %%
# update the topics table with the preprocessed topics, use tqdm to show progress bar
for index, row in tqdm.tqdm(topics_df.iterrows()):
    cur.execute("UPDATE topics SET topics_preprocessed = %s WHERE topic = %s", (row['topics_preprocessed'], row['topic']))
    conn.commit()
# Out:
# 67750it [00:34, 1937.82it/s]

# %%
# add a new column to the resources table with SERIAL PRIMARY KEY
cur.execute("ALTER TABLE resources ADD COLUMN id SERIAL PRIMARY KEY")
conn.commit()

# %%
# for each row in the resources table where id = row id, update the heading and content columns with the preprocessed heading and content
for index, row in tqdm.tqdm(df.iterrows()):
    # update heading_preprocessed column
    print(row['id'])
    cur.execute("UPDATE resources SET heading_preprocessed = %s WHERE id = %s", (row['heading_preprocessed'], row['id']))
    # update content_preprocessed column
    cur.execute("UPDATE resources SET content_preprocessed = %s WHERE id = %s", (row['content_preprocessed'], row['id']))
    # update heading_ngrams column
    cur.execute("UPDATE resources SET heading_ngrams = %s WHERE id = %s", (row['heading_ngrams'], row['id']))
    # update content_ngrams column
    cur.execute("UPDATE resources SET content_ngrams = %s WHERE id = %s", (row['content_ngrams'], row['id']))
    conn.commit()

# close the cursor and connection
cur.close()
conn.close()

# %%
# copy the resources table into a new resourcesbackup table
cur.execute("CREATE TABLE resourcesbackup AS TABLE resources")
conn.commit()
